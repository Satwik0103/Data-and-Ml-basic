# %% [markdown]
# # Assignment 3

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Loading the data

# %%
data=pd.read_csv(r'C:\DAm project\Data-and-Ml-basic\Project\winequalitytest.csv')
data.head()
# Out:
#     type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0  white            7.0              0.27         0.36            20.7
# 1  white            6.3              0.30         0.34             1.6
# 2  white            8.1              0.28         0.40             6.9
# 3  white            7.2              0.23         0.32             8.5
# 4  white            7.2              0.23         0.32             8.5
#
#    chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0      0.045                 45.0                 170.0   1.0010  3.00
# 1      0.049                 14.0                 132.0   0.9940  3.30
# 2      0.050                 30.0                  97.0   0.9951  3.26
# 3      0.058                 47.0                 186.0   0.9956  3.19
# 4      0.058                 47.0                 186.0   0.9956  3.19
#
#    sulphates  alcohol  quality
# 0       0.45      8.8        6
# 1       0.49      9.5        6
# ...

# %%
length1=data.shape[0]
length1
# Out:
# 6497

# %%
#Displaying first 5 data of the data set
data.head(5)
# Out:
#     type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0  white            7.0              0.27         0.36            20.7
# 1  white            6.3              0.30         0.34             1.6
# 2  white            8.1              0.28         0.40             6.9
# 3  white            7.2              0.23         0.32             8.5
# 4  white            7.2              0.23         0.32             8.5
#
#    chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0      0.045                 45.0                 170.0   1.0010  3.00
# 1      0.049                 14.0                 132.0   0.9940  3.30
# 2      0.050                 30.0                  97.0   0.9951  3.26
# 3      0.058                 47.0                 186.0   0.9956  3.19
# 4      0.058                 47.0                 186.0   0.9956  3.19
#
#    sulphates  alcohol  quality
# 0       0.45      8.8        6
# 1       0.49      9.5        6
# ...

# %%
#Displaying last 5 elements of the dataset
data.tail(5)
# Out:
#      type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 6492  red            6.2             0.600         0.08             2.0
# 6493  red            5.9             0.550         0.10             2.2
# 6494  red            6.3             0.510         0.13             2.3
# 6495  red            5.9             0.645         0.12             2.0
# 6496  red            6.0             0.310         0.47             3.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 6492      0.090                 32.0                  44.0  0.99490  3.45
# 6493      0.062                 39.0                  51.0  0.99512  3.52
# 6494      0.076                 29.0                  40.0  0.99574  3.42
# 6495      0.075                 32.0                  44.0  0.99547  3.57
# 6496      0.067                 18.0                  42.0  0.99549  3.39
#
#       sulphates  alcohol  quality
# 6492       0.58     10.5        5
# ...

# %% [markdown]
# # Describe the data in multiple- way

# %%
#Describing the total no of data in dataset of each column
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6497 entries, 0 to 6496
# Data columns (total 13 columns):
# type                    6497 non-null object
# fixed acidity           6487 non-null float64
# volatile acidity        6489 non-null float64
# citric acid             6494 non-null float64
# residual sugar          6495 non-null float64
# chlorides               6495 non-null float64
# free sulfur dioxide     6497 non-null float64
# total sulfur dioxide    6497 non-null float64
# density                 6497 non-null float64
# pH                      6488 non-null float64
# sulphates               6493 non-null float64
# alcohol                 6497 non-null float64
# quality                 6497 non-null int64
# dtypes: float64(11), int64(1), object(1)
# memory usage: 659.9+ KB

# %%
#Describing the data on basis of count mean std min max value in each column
data.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    6487.000000       6489.000000  6494.000000     6495.000000
# mean        7.216579          0.339691     0.318722        5.444326
# std         1.296750          0.164649     0.145265        4.758125
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.400000          0.230000     0.250000        1.800000
# 50%         7.000000          0.290000     0.310000        3.000000
# 75%         7.700000          0.400000     0.390000        8.100000
# max        15.900000          1.580000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  6495.000000          6497.000000           6497.000000  6497.000000
# mean      0.056042            30.525319            115.744574     0.994697
# std       0.035036            17.749400             56.521855     0.002999
# ...

# %%
#Telling the shape of dataset total no of rows and columns
print(data.shape)
rows,column=data.shape
print('Rows are {0} \nColumns are {1}'.format(rows,column))
# Out:
# (6497, 13)
# Rows are 6497
# Columns are 13

# %%
#Data Set Index incremented 1 at at time
data.index
# Out:
# RangeIndex(start=0, stop=6497, step=1)

# %%
#Telling total size of data set
data.size
# Out:
# 84461

# %%
#Data type of each field of dataset
data.dtypes
# Out:
# type                     object
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# dtype: object

# %% [markdown]
# # Remove Insignificant columns

# %%
data
# Out:
#        type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0     white            7.0             0.270         0.36           20.70
# 1     white            6.3             0.300         0.34            1.60
# 2     white            8.1             0.280         0.40            6.90
# 3     white            7.2             0.230         0.32            8.50
# 4     white            7.2             0.230         0.32            8.50
# 5     white            8.1             0.280         0.40            6.90
# 6     white            6.2             0.320         0.16            7.00
# 7     white            7.0             0.270         0.36           20.70
# 8     white            6.3             0.300         0.34            1.60
# 9     white            8.1             0.220         0.43            1.50
# 10    white            8.1             0.270         0.41            1.45
# 11    white            8.6             0.230         0.40            4.20
# ...

# %% [markdown]
# No insignificant collumns in data set

# %% [markdown]
# # Check Missing value for each columns

# %%
data.isnull().sum()
# Out:
# type                     0
# fixed acidity           10
# volatile acidity         8
# citric acid              3
# residual sugar           2
# chlorides                2
# free sulfur dioxide      0
# total sulfur dioxide     0
# density                  0
# pH                       9
# sulphates                4
# alcohol                  0
# quality                  0
# dtype: int64

# %% [markdown]
# we have 38 nan values

# %%
#For eg to check the missing data of chlorides we do this
data[data.chlorides.isnull()]
# Out:
#       type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 98   white            9.8              0.36         0.46            10.5
# 747  white            7.2              0.29         0.40             7.6
#
#      chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 98         NaN                  4.0                  83.0   0.9956  2.89
# 747        NaN                 56.0                 177.0   0.9928  3.04
#
#      sulphates  alcohol  quality
# 98        0.30     10.1        4
# 747       0.32     11.5        6

# %%
#Missing values of PH
data[data.pH.isnull()]
# Out:
#        type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 54    white            6.8             0.200         0.59             0.9
# 139   white            8.1             0.280         0.39             1.9
# 440   white            6.7             0.220         0.37             1.6
# 587   white            6.1             0.320         0.25             1.7
# 697   white            7.5             0.310         0.51            14.8
# 972   white            6.8             0.220         0.35            17.5
# 4892  white            6.5             0.230         0.38             1.3
# 6428    red            NaN             0.440         0.09             2.2
# 6429    red            NaN             0.705         0.10             2.8
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density  pH  \
# 54        0.147                 38.0                 132.0  0.99300 NaN
# 139       0.029                 18.0                  79.0  0.99230 NaN
# ...

# %% [markdown]
# # Remove rows with missing values

# %% [markdown]
# We will convert all null values of old_index column into -1 so that we can set a difference between both dataframes

# %%
#Filling all nan value with -1
data.pH.fillna(-1,inplace=True)
data.sulphates.fillna(-1,inplace=True)
data.chlorides.fillna(-1,inplace=True)
data
# Out:
#        type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0     white            7.0             0.270         0.36           20.70
# 1     white            6.3             0.300         0.34            1.60
# 2     white            8.1             0.280         0.40            6.90
# 3     white            7.2             0.230         0.32            8.50
# 4     white            7.2             0.230         0.32            8.50
# 5     white            8.1             0.280         0.40            6.90
# 6     white            6.2             0.320         0.16            7.00
# 7     white            7.0             0.270         0.36           20.70
# 8     white            6.3             0.300         0.34            1.60
# 9     white            8.1             0.220         0.43            1.50
# 10    white            8.1             0.270         0.41            1.45
# 11    white            8.6             0.230         0.40            4.20
# ...

# %%
#Missing values of PH
data[data.pH.isnull()]
# Out:
# Empty DataFrame
# Columns: [type, fixed acidity, volatile acidity, citric acid, residual sugar, chlorides, free sulfur dioxide, total sulfur dioxide, density, pH, sulphates, alcohol, quality]
# Index: []

# %%
data.isnull().sum()
# Out:
# type                     0
# fixed acidity           10
# volatile acidity         8
# citric acid              3
# residual sugar           2
# chlorides                0
# free sulfur dioxide      0
# total sulfur dioxide     0
# density                  0
# pH                       0
# sulphates                0
# alcohol                  0
# quality                  0
# dtype: int64

# %% [markdown]
# Now there are no null values in pH sulphates and chlorides

# %%
duplicate=(data.duplicated())
data[duplicate]
# Out:
#        type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 4     white            7.2             0.230         0.32            8.50
# 5     white            8.1             0.280         0.40            6.90
# 7     white            7.0             0.270         0.36           20.70
# 8     white            6.3             0.300         0.34            1.60
# 39    white            7.3             0.240         0.39           17.95
# 48    white            7.0             0.310         0.26            7.40
# 61    white            6.0             0.190         0.26           12.40
# 63    white            6.6             0.380         0.15            4.60
# 74    white            6.7             0.230         0.31            2.10
# 75    white            7.4             0.240         0.29           10.10
# 88    white            7.1             0.430         0.61           11.80
# 89    white            7.1             0.440         0.62           11.80
# ...

# %%
#Total duplicate values in dataset
data[duplicate].shape
# Out:
# (1168, 13)

# %%
#Removing duplicate values
data.drop_duplicates(inplace=True)
#New data shape
data.shape
# Out:
# (5329, 13)

# %% [markdown]
# # Formatting your Data – making data types compaitable with other data types.

# %%
data.dtypes
# Out:
# type                     object
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# dtype: object

# %%
data.get_dtype_counts()
# Out:
# float64    11
# int64       1
# object      1
# dtype: int64

# %% [markdown]
# Since we have compatible data so we do not need to formate our data type
